# %%
import pdfplumber
import os
import pandas as pd
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt

# %%
pdf_path = os.path.join(os.path.expanduser("~/Desktop/Trading/Data"), "spdr-sector-and-industry-dashboard.pdf")

pages_to_extract = [5, 6, 7]

with pdfplumber.open(pdf_path) as pdf:
    for i in pages_to_extract:
        page = pdf.pages[i]
        tables = page.extract_tables()
        print(f"\n--- Page {i+1}: Found {len(tables)} tables ---")
        for j, table in enumerate(tables):
            print(f"\nTable {j+1}:")
            for row in table:
                print(row)
# Out:
# --- Page 6: Found 2 tables ---
#
# Table 1:
# ['ETF Name', 'Fundamentals', None, None, None, None, 'International\nExposure', 'Macro Sensitivies (Beta)', None, None, None, None]
# [None, 'Price\nto\nBook', 'Price to\nEarnings\n(FY1)', 'Return\non Equity\n(%)', 'LT\nDebt to\nCapital\n(%)', 'EST\n3–5\nYears\nEPS\nGrowth\n(%)', '% Foreign Sales', 'US $\n(36 Mth)', 'US\n10 Year\nYield\n(36 Mth)', 'Brent\nCrude Oil\n(36 Mth)', 'AUM ($M)', '3 Month\nFund Flow\n($M)']
#
# Table 2:
# ['Kensho', None, None, None, None, None, None, None, None, None, None, None, None, None]
# ['KOMP', 'SPDR Kensho S&P New Economies ETF', '2.27', '16.7', '6.8', '33.37', '14.2', '39.14', '-1.40', '-0.48', '-0.03', '1,950', '26', '5.0']
# ['FITE', 'SPDR S&P Kensho Future Security ETF', '2.71', '20.7', '8.9', '28.82', '12.4', '42.75', '-0.72', '-0.30', '-0.03', '83', '6', '0.6']
# ['ROKT', 'SPDR S&P Kensho Final Frontier ETF', '2.47', '20.2', '14.0', '44.37', '8.5', '36.56', '-1.19', '-0.34', '-0.03', '19', '0', '0.2']
# ['CNRG', 'SPDR S&P Kensho Clean Power ETF', '0.96', '14.5', '7.5', '44.91', '15.5', '26.34', '-1.69', '-0.60', '-0.34', '118', '-17', '1.2']
# [None, 'SPDR S&P Kensho Smart Mobility ETF', '1.67', '12.5', '1.0', '33.00', '17.1', '53.31', '-1.79', '-0.56', '-0.02', '20', '-3', '0.1']
# ['SIMS', 'SPDR S&P Kensho Intelligent\nStructures ETF', '2.33', '16.5', '10.9', '33.02', '10.9', '32.20', '-1.44', '-0.46', '0.01', '8', '-1', '0.0']
# ['Industry', None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, 'SPDR S&P Biotech ETF', '3.27', '15.6', '-13.0', '36.65', '7.2', '18.03', '-1.30', '-0.38', '-0.16', '4,885', '-731', '787.3']
# ['XHS', 'SPDR S&P Health Care Services ETF', '2.29', '16.5', '1.9', '48.74', '11.4', '2.20', '-1.27', '-0.42', '0.04', '88', '12', '0.7']
# ['XHE', 'SPDR S&P Health Care Equipment ETF', '2.57', '18.4', '-0.5', '33.83', '13.4', '33.57', '-1.62', '-0.47', '-0.08', '174', '-24', '1.4']
# ['XPH', 'SPDR S&P Pharmaceuticals ETF', '2.70', '10.3', '3.0', '40.03', '5.3', '21.58', '-1.16', '-0.35', '-0.03', '158', '2', '2.2']
# ['XSD', 'SPDR S&P Semiconductor ETF', '3.04', '23.6', '8.0', '18.94', '19.8', '72.89', '-1.43', '-0.58', '-0.04', '1,039', '-95', '11.6']
# ['XSW', 'SPDR S&P Software & Services ETF', '3.99', '22.6', '4.4', '34.90', '14.5', '32.07', '-0.60', '-0.43', '-0.06', '460', '44', '8.5']
# ['XITK', 'SPDR FactSet Innovative\nTechnology ETF', '4.15', '24.6', '3.8', '21.13', '17.1', '38.42', '-0.79', '-0.40', '-0.07', '89', '1', '1.0']
# [None, 'SPDR NYSE Technology ETF', '5.69', '23.4', '25.8', '28.47', '17.0', '55.56', '-1.44', '-0.57', '-0.04', '843', '20', '3.5']
# [None, 'SPDR S&P Oil & Gas Exploration &\nProduction ETF', '1.30', '10.7', '10.4', '32.81', '6.7', '13.10', '-0.69', '-0.14', '0.46', '2,219', '-74', '401.1']
# [None, 'SPDR S&P Oil & Gas Equipment &\nServices ETF', '1.32', '14.2', '12.6', '33.64', '11.7', '46.46', '-1.13', '-0.15', '0.63', '186', '-1', '4.5']
# ['XRT', 'SPDR S&P Retail ETF', '1.81', '13.2', '19.5', '59.82', '7.4', '10.37', '-1.34', '-0.38', '-0.03', '262', '-42', '438.5']
#
# --- Page 7: Found 2 tables ---
#
# Table 1:
# ['ETF Name', 'Fundamentals', None, None, None, None, 'International\nExposure', 'Macro Sensitivies (Beta)', None, None, None, None]
# [None, 'Price\nto\nBook', 'Price to\nEarnings\n(FY1)', 'Return on\nEquity\n(%)', 'LT\nDebt to\nCapital\n(%)', 'EST\n3–5\nYears\nEPS\nGrowth\n(%)', '% Foreign Sales', 'US $\n(36 Mth)', 'US\n10 Year\nYield\n(36 Mth)', 'Brent\nCrude Oil\n(36 Mth)', 'AUM ($M)', '3 Month\nFund Flow\n($M)']
#
# Table 2:
# ['Industry (Cont’d)', None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, 'SPDR S&P Homebuilders ETF', '2.20', '12.5', '26.6', '42.23', '9.5', '10.72', '-2.20', '-0.62', '-0.04', '1,371', '-356', '234.8']
# [None, 'SPDR S&P Telecom ETF', '2.21', '18.6', '-0.7', '50.58', '12.0', '31.86', '-1.30', '-0.51', '-0.20', '130', '-4', '1.2']
# ['XAR', 'SPDR S&P Aerospace & Defense ETF', '3.87', '25.2', '10.1', '46.85', '11.6', '29.47', '-1.21', '-0.38', '-0.03', '2,609', '44', '22.2']
# [None, 'SPDR S&P Transportation ETF', '1.95', '13.5', '11.1', '41.85', '23.2', '15.85', '-1.31', '-0.47', '0.07', '160', '-20', '1.8']
# [None, 'SPDR S&P Metals and Mining ETF', '1.52', '14.3', '9.4', '25.18', '16.4', '38.22', '-1.95', '-0.45', '-0.05', '1,561', '41', '97.0']
# ['KRE', 'SPDR S&P Regional Banking ETF', '1.10', '10.9', '9.1', '17.65', '11.9', '2.16', '-1.19', '-0.36', '0.22', '3,472', '-1,382', '744.8']
# [None, 'SPDR S&P Insurance ETF', '1.77', '12.4', '16.3', '28.55', '9.3', '23.19', '-1.02', '-0.25', '0.11', '1,014', '-48', '56.4']
# [None, 'SPDR S&P Capital Markets ETF', '2.99', '15.1', '20.5', '36.37', '12.9', '25.02', '-1.41', '-0.46', '0.11', '477', '-23', '6.4']
# [None, 'SPDR S&P Bank ETF', '1.19', '10.8', '10.3', '20.37', '11.0', '4.84', '-1.24', '-0.38', '0.20', '1,965', '-246', '130.3']
# ['Sector', None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, 'Communication Services Select Sector\nSPDR Fund', '2.96', '16.9', '18.1', '39.98', '6.9', '36.86', '-1.52', '-0.51', '0.03', '20,326', '337', '480.1']
# [None, 'Real Estate Select Sector SPDR Fund', '2.85', '39.4', '19.7', '52.09', '8.5', '16.69', '-1.72', '-0.50', '-0.10', '7,361', '225', '238.4']
# [None, 'Utilities Select Sector SPDR Fund', '2.28', '18.1', '15.1', '55.46', '7.9', '1.02', '-1.39', '-0.31', '-0.10', '18,013', '884', '785.0']
# ['XLF', 'Financial Select Sector SPDR Fund', '2.38', '16.9', '20.4', '34.71', '11.0', '28.59', '-1.26', '-0.36', '0.14', '51,999', '2,350', '2,359.3']
# ['XLE', 'Energy Select Sector SPDR Fund', '2.19', '15.6', '15.9', '28.74', '4.6', '34.19', '-0.99', '-0.18', '0.46', '33,620', '-3,015', '1,436.8']
# [None, 'Consumer Discretionary Select Sector\nSPDR Fund', '5.68', '23.8', '26.3', '61.04', '9.5', '34.79', '-0.93', '-0.46', '-0.04', '20,109', '-325', '768.5']
# ['XLP', 'Consumer Staples Select Sector\nSPDR Fund', '4.53', '20.1', '25.2', '53.21', '5.7', '37.68', '-0.89', '-0.23', '-0.03', '16,816', '-22', '996.2']
# ['XLV', 'Health Care Select Sector SPDR Fund', '4.82', '17.7', '29.2', '46.60', '12.2', '31.62', '-1.03', '-0.25', '0.10', '37,815', '-134', '1,236.1']
# [None, 'Technology Select Sector SPDR Fund', '8.13', '24.8', '25.9', '34.59', '16.5', '53.47', '-1.23', '-0.53', '-0.04', '64,655', '-463', '1,106.1']
#
# --- Page 8: Found 2 tables ---
#
# Table 1:
# ['ETF Name', 'Fundamentals', None, None, None, None, 'International\nExposure', 'Macro Sensitivies (Beta)', None, None, None, None]
# [None, 'Price\nto\nBook', 'Price to\nEarnings\n(FY1)', 'Return on\nEquity\n(%)', 'LT\nDebt to\nCapital\n(%)', 'EST\n3–5\nYears\nEPS\nGrowth\n(%)', '% Foreign Sales', 'US $\n(36 Mth)', 'US\n10 Year\nYield\n(36 Mth)', 'Brent\nCrude Oil\n(36 Mth)', 'AUM ($M)', '3 Month\nFund Flow\n($M)']
#
# Table 2:
# ['Sector (Cont’d)', None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, 'Industrial Select Sector SPDR Fund', '5.52', '21.7', '33.1', '46.75', '12.1', '33.06', '-1.35', '-0.37', '-0.01', '20,072', '-572', '1,240.8']
# [None, 'Materials Select Sector SPDR Fund', '2.65', '19.7', '17.4', '35.64', '10.0', '50.62', '-1.69', '-0.37', '0.04', '5,226', '-356', '538.5']

# %%
pdf_path = os.path.join(os.path.expanduser("~/Desktop/Trading/Data"), "spdr-sector-and-industry-dashboard.pdf")

pages_to_extract = [5, 6, 7]

dfs = []

with pdfplumber.open(pdf_path) as pdf:
    for i in pages_to_extract:
        page = pdf.pages[i]
        tables = page.extract_tables()

        if tables:
            print(f"--- Page {i+1}: Found {len(tables)} tables ---")

            # Get the correct header row (second row of Table 1)
            raw_header = tables[0][1]

            # Fix the header
            raw_header[0] = 'Ticker'
            raw_header.insert(1, 'ETF Name')
            raw_header.insert(2,'P_B')
            raw_header.insert(3, 'P_E')
            raw_header.insert(4,'ROE')
            raw_header.insert(5, 'LT_Debt_to_Capital')
            raw_header.insert(6,'EPS_growth_4_years')
            raw_header.insert(7, '%_foriegn_sales')
            raw_header.insert(8,'beta_USD')
            raw_header.insert(9, 'beta_10_yr_treasury')
            raw_header.insert(10,'beta_crude_oil')
            raw_header.insert(11, 'AUM')
            raw_header.insert(12,'3_month_money_flow')


            print(f"⚙️ Adjusted header (len={len(raw_header)}): {raw_header}")

            # Process data rows from Table 2
            for row in tables[1][1:]:
                # Trim or pad each data row to match the header length
                if len(row) < len(raw_header):
                    row += [None] * (len(raw_header) - len(row))
                elif len(row) > len(raw_header):
                    row = row[:len(raw_header)]

                dfs.append(dict(zip(raw_header, row)))

# Convert to DataFrame
full_df = pd.DataFrame(dfs)

# Quick check
print(full_df.shape)
# Out:
# --- Page 6: Found 2 tables ---
# ⚙️ Adjusted header (len=24): ['Ticker', 'ETF Name', 'P_B', 'P_E', 'ROE', 'LT_Debt_to_Capital', 'EPS_growth_4_years', '%_foriegn_sales', 'beta_USD', 'beta_10_yr_treasury', 'beta_crude_oil', 'AUM', '3_month_money_flow', 'Price\nto\nBook', 'Price to\nEarnings\n(FY1)', 'Return\non Equity\n(%)', 'LT\nDebt to\nCapital\n(%)', 'EST\n3–5\nYears\nEPS\nGrowth\n(%)', '% Foreign Sales', 'US $\n(36 Mth)', 'US\n10 Year\nYield\n(36 Mth)', 'Brent\nCrude Oil\n(36 Mth)', 'AUM ($M)', '3 Month\nFund Flow\n($M)']
# --- Page 7: Found 2 tables ---
# ⚙️ Adjusted header (len=24): ['Ticker', 'ETF Name', 'P_B', 'P_E', 'ROE', 'LT_Debt_to_Capital', 'EPS_growth_4_years', '%_foriegn_sales', 'beta_USD', 'beta_10_yr_treasury', 'beta_crude_oil', 'AUM', '3_month_money_flow', 'Price\nto\nBook', 'Price to\nEarnings\n(FY1)', 'Return on\nEquity\n(%)', 'LT\nDebt to\nCapital\n(%)', 'EST\n3–5\nYears\nEPS\nGrowth\n(%)', '% Foreign Sales', 'US $\n(36 Mth)', 'US\n10 Year\nYield\n(36 Mth)', 'Brent\nCrude Oil\n(36 Mth)', 'AUM ($M)', '3 Month\nFund Flow\n($M)']
# --- Page 8: Found 2 tables ---
# ⚙️ Adjusted header (len=24): ['Ticker', 'ETF Name', 'P_B', 'P_E', 'ROE', 'LT_Debt_to_Capital', 'EPS_growth_4_years', '%_foriegn_sales', 'beta_USD', 'beta_10_yr_treasury', 'beta_crude_oil', 'AUM', '3_month_money_flow', 'Price\nto\nBook', 'Price to\nEarnings\n(FY1)', 'Return on\nEquity\n(%)', 'LT\nDebt to\nCapital\n(%)', 'EST\n3–5\nYears\nEPS\nGrowth\n(%)', '% Foreign Sales', 'US $\n(36 Mth)', 'US\n10 Year\nYield\n(36 Mth)', 'Brent\nCrude Oil\n(36 Mth)', 'AUM ($M)', '3 Month\nFund Flow\n($M)']
# (39, 25)

# %%
# Drop rows with index 6 and 27
clean_df = full_df.drop(index=[6, 27,29]).reset_index(drop=True)

print(clean_df.shape)
clean_df.head(45)
# Out:
# (36, 25)
#    Ticker                                          ETF Name   P_B   P_E  \
# 0    KOMP                 SPDR Kensho S&P New Economies ETF  2.27  16.7
# 1    FITE               SPDR S&P Kensho Future Security ETF  2.71  20.7
# 2    ROKT                SPDR S&P Kensho Final Frontier ETF  2.47  20.2
# 3    CNRG                   SPDR S&P Kensho Clean Power ETF  0.96  14.5
# 4    None                SPDR S&P Kensho Smart Mobility ETF  1.67  12.5
# 5    SIMS       SPDR S&P Kensho Intelligent\nStructures ETF  2.33  16.5
# 6    None                              SPDR S&P Biotech ETF  3.27  15.6
# 7     XHS                 SPDR S&P Health Care Services ETF  2.29  16.5
# 8     XHE                SPDR S&P Health Care Equipment ETF  2.57  18.4
# 9     XPH                      SPDR S&P Pharmaceuticals ETF  2.70  10.3
# 10    XSD                        SPDR S&P Semiconductor ETF  3.04  23.6
# 11    XSW                  SPDR S&P Software & Services ETF  3.99  22.6
# 12   XITK           SPDR FactSet Innovative\nTechnology ETF  4.15  24.6
# 13   None                          SPDR NYSE Technology ETF  5.69  23.4
# 14   None  SPDR S&P Oil & Gas Exploration &\nProduction ETF  1.30  10.7
# 15   None      SPDR S&P Oil & Gas Equipment &\nServices ETF  1.32  14.2
# 16    XRT                               SPDR S&P Retail ETF  1.81  13.2
# 17   None                         SPDR S&P Homebuilders ETF  2.20  12.5
# 18   None                              SPDR S&P Telecom ETF  2.21  18.6
# 19    XAR                  SPDR S&P Aerospace & Defense ETF  3.87  25.2
# 20   None                       SPDR S&P Transportation ETF  1.95  13.5
# 21   None                    SPDR S&P Metals and Mining ETF  1.52  14.3
# 22    KRE                     SPDR S&P Regional Banking ETF  1.10  10.9
# 23   None                            SPDR S&P Insurance ETF  1.77  12.4
# 24   None                      SPDR S&P Capital Markets ETF  2.99  15.1
# 25   None                                 SPDR S&P Bank ETF  1.19  10.8
# 26   None   Communication Services Select Sector\nSPDR Fund  2.96  16.9
# 27   None                 Utilities Select Sector SPDR Fund  2.28  18.1
# 28    XLF                 Financial Select Sector SPDR Fund  2.38  16.9
# 29    XLE                    Energy Select Sector SPDR Fund  2.19  15.6
# 30   None   Consumer Discretionary Select Sector\nSPDR Fund  5.68  23.8
# 31    XLP         Consumer Staples Select Sector\nSPDR Fund  4.53  20.1
# 32    XLV               Health Care Select Sector SPDR Fund  4.82  17.7
# 33   None                Technology Select Sector SPDR Fund  8.13  24.8
# 34   None                Industrial Select Sector SPDR Fund  5.52  21.7
# 35   None                 Materials Select Sector SPDR Fund  2.65  19.7
#
#       ROE LT_Debt_to_Capital EPS_growth_4_years %_foriegn_sales beta_USD  \
# 0     6.8              33.37               14.2           39.14    -1.40
# 1     8.9              28.82               12.4           42.75    -0.72
# 2    14.0              44.37                8.5           36.56    -1.19
# 3     7.5              44.91               15.5           26.34    -1.69
# 4     1.0              33.00               17.1           53.31    -1.79
# 5    10.9              33.02               10.9           32.20    -1.44
# 6   -13.0              36.65                7.2           18.03    -1.30
# 7     1.9              48.74               11.4            2.20    -1.27
# 8    -0.5              33.83               13.4           33.57    -1.62
# 9     3.0              40.03                5.3           21.58    -1.16
# 10    8.0              18.94               19.8           72.89    -1.43
# 11    4.4              34.90               14.5           32.07    -0.60
# 12    3.8              21.13               17.1           38.42    -0.79
# 13   25.8              28.47               17.0           55.56    -1.44
# 14   10.4              32.81                6.7           13.10    -0.69
# 15   12.6              33.64               11.7           46.46    -1.13
# 16   19.5              59.82                7.4           10.37    -1.34
# 17   26.6              42.23                9.5           10.72    -2.20
# 18   -0.7              50.58               12.0           31.86    -1.30
# 19   10.1              46.85               11.6           29.47    -1.21
# 20   11.1              41.85               23.2           15.85    -1.31
# 21    9.4              25.18               16.4           38.22    -1.95
# 22    9.1              17.65               11.9            2.16    -1.19
# 23   16.3              28.55                9.3           23.19    -1.02
# 24   20.5              36.37               12.9           25.02    -1.41
# 25   10.3              20.37               11.0            4.84    -1.24
# 26   18.1              39.98                6.9           36.86    -1.52
# 27   15.1              55.46                7.9            1.02    -1.39
# 28   20.4              34.71               11.0           28.59    -1.26
# 29   15.9              28.74                4.6           34.19    -0.99
# 30   26.3              61.04                9.5           34.79    -0.93
# 31   25.2              53.21                5.7           37.68    -0.89
# 32   29.2              46.60               12.2           31.62    -1.03
# 33   25.9              34.59               16.5           53.47    -1.23
# 34   33.1              46.75               12.1           33.06    -1.35
# 35   17.4              35.64               10.0           50.62    -1.69
#
#    beta_10_yr_treasury  ... Return\non Equity\n(%) LT\nDebt to\nCapital\n(%)  \
# 0                -0.48  ...                    NaN                      None
# 1                -0.30  ...                    NaN                      None
# 2                -0.34  ...                    NaN                      None
# 3                -0.60  ...                    NaN                      None
# 4                -0.56  ...                    NaN                      None
# 5                -0.46  ...                    NaN                      None
# 6                -0.38  ...                    NaN                      None
# 7                -0.42  ...                    NaN                      None
# 8                -0.47  ...                    NaN                      None
# 9                -0.35  ...                    NaN                      None
# 10               -0.58  ...                    NaN                      None
# 11               -0.43  ...                    NaN                      None
# 12               -0.40  ...                    NaN                      None
# 13               -0.57  ...                    NaN                      None
# 14               -0.14  ...                    NaN                      None
# 15               -0.15  ...                    NaN                      None
# 16               -0.38  ...                    NaN                      None
# 17               -0.62  ...                    NaN                      None
# 18               -0.51  ...                    NaN                      None
# 19               -0.38  ...                    NaN                      None
# 20               -0.47  ...                    NaN                      None
# 21               -0.45  ...                    NaN                      None
# 22               -0.36  ...                    NaN                      None
# 23               -0.25  ...                    NaN                      None
# 24               -0.46  ...                    NaN                      None
# 25               -0.38  ...                    NaN                      None
# 26               -0.51  ...                    NaN                      None
# 27               -0.31  ...                    NaN                      None
# 28               -0.36  ...                    NaN                      None
# 29               -0.18  ...                    NaN                      None
# 30               -0.46  ...                    NaN                      None
# 31               -0.23  ...                    NaN                      None
# 32               -0.25  ...                    NaN                      None
# 33               -0.53  ...                    NaN                      None
# 34               -0.37  ...                    NaN                      None
# 35               -0.37  ...                    NaN                      None
#
#    EST\n3–5\nYears\nEPS\nGrowth\n(%) % Foreign Sales US $\n(36 Mth)  \
# 0                               None            None           None
# 1                               None            None           None
# 2                               None            None           None
# 3                               None            None           None
# 4                               None            None           None
# 5                               None            None           None
# 6                               None            None           None
# 7                               None            None           None
# 8                               None            None           None
# 9                               None            None           None
# 10                              None            None           None
# 11                              None            None           None
# 12                              None            None           None
# 13                              None            None           None
# 14                              None            None           None
# 15                              None            None           None
# 16                              None            None           None
# 17                              None            None           None
# 18                              None            None           None
# 19                              None            None           None
# 20                              None            None           None
# 21                              None            None           None
# 22                              None            None           None
# 23                              None            None           None
# 24                              None            None           None
# 25                              None            None           None
# 26                              None            None           None
# 27                              None            None           None
# 28                              None            None           None
# 29                              None            None           None
# 30                              None            None           None
# 31                              None            None           None
# 32                              None            None           None
# 33                              None            None           None
# 34                              None            None           None
# 35                              None            None           None
#
#     US\n10 Year\nYield\n(36 Mth) Brent\nCrude Oil\n(36 Mth) AUM ($M)  \
# 0                           None                       None     None
# 1                           None                       None     None
# 2                           None                       None     None
# 3                           None                       None     None
# 4                           None                       None     None
# 5                           None                       None     None
# 6                           None                       None     None
# 7                           None                       None     None
# 8                           None                       None     None
# 9                           None                       None     None
# 10                          None                       None     None
# 11                          None                       None     None
# 12                          None                       None     None
# 13                          None                       None     None
# 14                          None                       None     None
# 15                          None                       None     None
# 16                          None                       None     None
# 17                          None                       None     None
# 18                          None                       None     None
# 19                          None                       None     None
# 20                          None                       None     None
# 21                          None                       None     None
# 22                          None                       None     None
# 23                          None                       None     None
# 24                          None                       None     None
# 25                          None                       None     None
# 26                          None                       None     None
# 27                          None                       None     None
# 28                          None                       None     None
# 29                          None                       None     None
# 30                          None                       None     None
# 31                          None                       None     None
# 32                          None                       None     None
# 33                          None                       None     None
# 34                          None                       None     None
# 35                          None                       None     None
#
#    3 Month\nFund Flow\n($M) Return on\nEquity\n(%)
# 0                      None                    NaN
# 1                      None                    NaN
# 2                      None                    NaN
# 3                      None                    NaN
# 4                      None                    NaN
# 5                      None                    NaN
# 6                      None                    NaN
# 7                      None                    NaN
# 8                      None                    NaN
# 9                      None                    NaN
# 10                     None                    NaN
# 11                     None                    NaN
# 12                     None                    NaN
# 13                     None                    NaN
# 14                     None                    NaN
# 15                     None                    NaN
# 16                     None                    NaN
# 17                     None                    NaN
# 18                     None                    NaN
# 19                     None                    NaN
# 20                     None                    NaN
# 21                     None                    NaN
# 22                     None                    NaN
# 23                     None                    NaN
# 24                     None                    NaN
# 25                     None                    NaN
# 26                     None                    NaN
# 27                     None                    NaN
# 28                     None                    NaN
# 29                     None                    NaN
# 30                     None                    NaN
# 31                     None                    NaN
# 32                     None                    NaN
# 33                     None                    NaN
# 34                     None                    NaN
# 35                     None                    NaN
#
# [36 rows x 25 columns]

# %%
clean_df[['P_E', 'EPS_growth_4_years']] = clean_df[['P_E', 'EPS_growth_4_years']].apply(
    lambda col: pd.to_numeric(col, errors='coerce')
)

# Drop rows where either is missing or zero (to avoid log(0) errors)
reg_df = clean_df.dropna(subset=['P_E', 'EPS_growth_4_years']).copy()
reg_df = reg_df[(reg_df['P_E'] > 0) & (reg_df['EPS_growth_4_years'] > 0)]
reg_df['ln_PE'] = np.log(reg_df['P_E'])

reg_df.head()
# Out:
#   Ticker                             ETF Name   P_B   P_E   ROE  \
# 0   KOMP    SPDR Kensho S&P New Economies ETF  2.27  16.7   6.8
# 1   FITE  SPDR S&P Kensho Future Security ETF  2.71  20.7   8.9
# 2   ROKT   SPDR S&P Kensho Final Frontier ETF  2.47  20.2  14.0
# 3   CNRG      SPDR S&P Kensho Clean Power ETF  0.96  14.5   7.5
# 4   None   SPDR S&P Kensho Smart Mobility ETF  1.67  12.5   1.0
#
#   LT_Debt_to_Capital  EPS_growth_4_years %_foriegn_sales beta_USD  \
# 0              33.37                14.2           39.14    -1.40
# 1              28.82                12.4           42.75    -0.72
# 2              44.37                 8.5           36.56    -1.19
# 3              44.91                15.5           26.34    -1.69
# 4              33.00                17.1           53.31    -1.79
#
#   beta_10_yr_treasury  ... LT\nDebt to\nCapital\n(%)  \
# 0               -0.48  ...                      None
# 1               -0.30  ...                      None
# 2               -0.34  ...                      None
# 3               -0.60  ...                      None
# 4               -0.56  ...                      None
#
#   EST\n3–5\nYears\nEPS\nGrowth\n(%) % Foreign Sales US $\n(36 Mth)  \
# 0                              None            None           None
# 1                              None            None           None
# 2                              None            None           None
# 3                              None            None           None
# 4                              None            None           None
#
#   US\n10 Year\nYield\n(36 Mth)  Brent\nCrude Oil\n(36 Mth) AUM ($M)  \
# 0                         None                        None     None
# 1                         None                        None     None
# 2                         None                        None     None
# 3                         None                        None     None
# 4                         None                        None     None
#
#   3 Month\nFund Flow\n($M) Return on\nEquity\n(%)     ln_PE
# 0                     None                    NaN  2.815409
# 1                     None                    NaN  3.030134
# 2                     None                    NaN  3.005683
# 3                     None                    NaN  2.674149
# 4                     None                    NaN  2.525729
#
# [5 rows x 26 columns]

# %%
# Calculate average P/E for those sector ETFs
average_pe_sector = reg_df['P_E'].mean()

print("📊 Average P/E for sector ETFs (rows 26-36):", average_pe_sector)
print(''' Use the avergae pe as the base for the percentage change in the pe for the underlying. Do NOT use the intercept. ''')
# Out:
# 📊 Average P/E for sector ETFs (rows 26-36): 17.3
#  Use the avergae pe as the base for the percentage change in the pe for the underlying. Do NOT use the intercept.

# %%
# Setup regression
X = sm.add_constant(reg_df['EPS_growth_4_years'])
y = reg_df['ln_PE']

model = sm.OLS(y, X).fit()
print(model.summary())

print(''' the coefficient is the expected p/e when the growth is 0. the coefficient beta is the expected percentage increase in the p/e per unit increase in the independent var, aka the growth  ''')


print('''
NO SIGNIFICANCE''')

print('''EXPECTATION OF A LOG LINEAR RELATIONSHIP PROBABLY MISSPECIFIED''')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  ln_PE   R-squared:                       0.067
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     2.427
# Date:                Mon, 14 Jul 2025   Prob (F-statistic):              0.129
# Time:                        09:49:01   Log-Likelihood:                -1.2482
# No. Observations:                  36   AIC:                             6.496
# Df Residuals:                      34   BIC:                             9.663
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  2.6279      0.129     20.343      0.000       2.365       2.890
# EPS_growth_4_years     0.0161      0.010      1.558      0.129      -0.005       0.037
# ==============================================================================
# Omnibus:                        6.004   Durbin-Watson:                   1.356
# Prob(Omnibus):                  0.050   Jarque-Bera (JB):                2.300
# Skew:                          -0.249   Prob(JB):                        0.317
# Kurtosis:                       1.867   Cond. No.                         37.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  the coefficient is the expected p/e when the growth is 0. the coefficient beta is the expected percentage increase in the p/e per unit increase in the independent var, aka the growth
#
# NO SIGNIFICANCE
# EXPECTATION OF A LOG LINEAR RELATIONSHIP PROBABLY MISSPECIFIED

# %%
# Isolate sector SPDR ETFs (rows 26 to 36)
sector_df = reg_df.loc[26:36].copy()

# Set up regression
X_sector = sm.add_constant(sector_df['EPS_growth_4_years'])
y_sector = sector_df['ln_PE']

model_sector = sm.OLS(y_sector, X_sector).fit()

print(model_sector.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  ln_PE   R-squared:                       0.364
# Model:                            OLS   Adj. R-squared:                  0.284
# Method:                 Least Squares   F-statistic:                     4.572
# Date:                Mon, 14 Jul 2025   Prob (F-statistic):             0.0649
# Time:                        09:49:01   Log-Likelihood:                 7.2748
# No. Observations:                  10   AIC:                            -10.55
# Df Residuals:                       8   BIC:                            -9.944
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  2.7077      0.125     21.582      0.000       2.418       2.997
# EPS_growth_4_years     0.0263      0.012      2.138      0.065      -0.002       0.055
# ==============================================================================
# Omnibus:                        0.279   Durbin-Watson:                   1.933
# Prob(Omnibus):                  0.870   Jarque-Bera (JB):                0.416
# Skew:                           0.227   Prob(JB):                        0.812
# Kurtosis:                       2.110   Cond. No.                         31.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Users/nicholassanso/anaconda3/envs/dsi/lib/python3.8/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
# Isolate sector SPDR ETFs (rows 26 to 36)
sector_df = reg_df.loc[26:36].copy()

# Convert beta_10_yr_treasury to numeric if not already
sector_df['beta_10_yr_treasury'] = pd.to_numeric(sector_df['beta_10_yr_treasury'], errors='coerce')

# Drop rows with missing values in either independent variable or ln_PE
sector_df = sector_df.dropna(subset=['EPS_growth_4_years', 'beta_10_yr_treasury', 'ln_PE'])

# Set up regression with two independent variables
X_sector = sector_df[['EPS_growth_4_years', 'beta_10_yr_treasury']]
X_sector = sm.add_constant(X_sector)  # add intercept

y_sector = sector_df['ln_PE']

# Fit model
model_sector = sm.OLS(y_sector, X_sector).fit()

# Print results
print(model_sector.summary())


print('''
NO SIGNIFICANCE, likely too many vars for the observations''')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  ln_PE   R-squared:                       0.440
# Model:                            OLS   Adj. R-squared:                  0.280
# Method:                 Least Squares   F-statistic:                     2.749
# Date:                Mon, 14 Jul 2025   Prob (F-statistic):              0.132
# Time:                        09:49:01   Log-Likelihood:                 7.9124
# No. Observations:                  10   AIC:                            -9.825
# Df Residuals:                       7   BIC:                            -8.917
# Df Model:                           2
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   2.6281      0.150     17.521      0.000       2.273       2.983
# EPS_growth_4_years      0.0188      0.015      1.292      0.237      -0.016       0.053
# beta_10_yr_treasury    -0.4258      0.436     -0.976      0.362      -1.458       0.606
# ==============================================================================
# Omnibus:                        0.475   Durbin-Watson:                   1.556
# Prob(Omnibus):                  0.788   Jarque-Bera (JB):                0.495
# Skew:                           0.123   Prob(JB):                        0.781
# Kurtosis:                       1.938   Cond. No.                         110.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# NO SIGNIFICANCE
# /Users/nicholassanso/anaconda3/envs/dsi/lib/python3.8/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
# Log-transform both variables
reg_df['ln_Growth'] = np.log(reg_df['EPS_growth_4_years'])

# Set up regression: ln_PE ~ ln_Growth
X = sm.add_constant(reg_df['ln_Growth'])
y = reg_df['ln_PE']

model = sm.OLS(y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  ln_PE   R-squared:                       0.082
# Model:                            OLS   Adj. R-squared:                  0.055
# Method:                 Least Squares   F-statistic:                     3.029
# Date:                Mon, 14 Jul 2025   Prob (F-statistic):             0.0908
# Time:                        09:49:01   Log-Likelihood:               -0.95305
# No. Observations:                  36   AIC:                             5.906
# Df Residuals:                      34   BIC:                             9.073
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.3382      0.279      8.387      0.000       1.772       2.905
# ln_Growth      0.1997      0.115      1.740      0.091      -0.033       0.433
# ==============================================================================
# Omnibus:                        6.591   Durbin-Watson:                   1.297
# Prob(Omnibus):                  0.037   Jarque-Bera (JB):                2.357
# Skew:                          -0.235   Prob(JB):                        0.308
# Kurtosis:                       1.838   Cond. No.                         18.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
